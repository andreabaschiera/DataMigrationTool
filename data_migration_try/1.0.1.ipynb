# %%
from openpyxl import load_workbook

# %%
from pathlib import Path
from typing import Optional, Tuple, List
from openpyxl import load_workbook
from openpyxl.worksheet.worksheet import Worksheet
from openpyxl.utils.cell import range_boundaries

# %%
def get_dest(wb, name: str) -> Optional[Tuple[Worksheet, str]]:
    dn = wb.defined_names.get(name)
    if dn is None:
        return None
    try:
        dests = list(dn.destinations)
    except Exception:
        return None  # For constants or invalid named ranges

    for sheet_name, ref in dests:
        if sheet_name in wb.sheetnames:
            return wb[sheet_name], ref  # Return the sheet and reference like "A1:B3"
    return None

# %%
def shape(ref: str) -> Tuple[int, int]:
    min_c, min_r, max_c, max_r = range_boundaries(ref)
    return (max_r - min_r + 1, max_c - min_c + 1)

# %%
def read_values(ws: Worksheet, ref: str) -> List[List[object]]:
    min_c, min_r, max_c, max_r = range_boundaries(ref)
    out = []
    for row in ws.iter_rows(min_row=min_r, max_row=max_r, min_col=min_c, max_col=max_c, values_only=True):
        out.append(list(row))
    return out

# %%
def write_values(ws: Worksheet, ref: str, values: List[List[object]]) -> None:
    min_c, min_r, max_c, max_r = range_boundaries(ref)
    for r_i, row in enumerate(values):
        for c_i, v in enumerate(row):
            ws.cell(row=min_r + r_i, column=min_c + c_i, value=v)

# %%
def transfer_same_names(source_path: Path, target_path: Path, output_path: Path) -> None:
    print(f"Loading source: {source_path}")
    src = load_workbook(source_path, data_only=True, keep_links=False)

    print(f"Loading target template: {target_path}")
    tgt = load_workbook(target_path, data_only=False, keep_links=False)

    src_names = set(src.defined_names.keys())
    tgt_names = set(tgt.defined_names.keys())

    common = sorted(src_names & tgt_names)
    copied = 0

    for name in common:
        s = get_dest(src, name)
        t = get_dest(tgt, name)
        if not s or not t:
            print(f"[SKIP] {name}: not a cell range.")
            continue

        s_ws, s_ref = s
        t_ws, t_ref = t
        
        if shape(s_ref) != shape(t_ref):
            print(f"[SKIP] {name}: different shape.")
            continue

        vals = read_values(s_ws, s_ref)
        write_values(t_ws, t_ref, vals)
        print(f"[OK] {name} copied.")
        copied += 1

    print(f"\n✅ Done! Copied {copied} named ranges.")
    tgt.save(output_path)

# %%
from pathlib import Path

# %%
source_path = Path(r"C:\path\to\your\OLD_filled_workbook.xlsx")  # old template with data
output_path = Path(r"C:\path\to\output\VSME-filled.xlsx")        # where to save the result

# ✅ Your target template path (what you sent)
target_path = Path(r"\data_migration_try\Template\VSME-Digital-Template-Sample-1.0.1.xlsx")

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Thibault.magro\OneDrive - EFRAG\Desktop\Git repository\Paper team\PaperTeam\data_migration_try

# %%
transfer_same_names(
    Path(r"Template\VSME-Digital-Template-Sample-1.0.1.xlsx"),
    Path(r"Template\VSME-Digital-Template-1.1.1.xlsx"),
    Path(r"output.xlsx")
)
# Out:
# Loading source: Template\VSME-Digital-Template-Sample-1.0.1.xlsx
# Loading target template: Template\VSME-Digital-Template-1.1.1.xlsx
# [SKIP] AddressOfSite: different shape.
# [SKIP] AmountOfEmissionToAir: different shape.
# [OK] AmountOfEmissionToAir_unit copied.
# [SKIP] AmountOfEmissionToSoil: different shape.
# [OK] AmountOfEmissionToSoil_unit copied.
# [SKIP] AmountOfEmissionToWater: different shape.
# [OK] AmountOfEmissionToWater_unit copied.
# [SKIP] AmountOfEmissionsTable: different shape.
# [OK] AmountOfWaterWithdrawnAtSitesLocatedInAreasOfHighWaterStress copied.
# [SKIP] AreaOfSiteInBiodiversitySensitiveArea: different shape.
# [OK] AreaOfSiteInBiodiversitySensitiveArea_unit copied.
# [OK] Assets copied.
# [OK] AverageNumberOfAnnualTrainingHoursPerFemaleEmployee copied.
# [OK] AverageNumberOfAnnualTrainingHoursPerMaleEmployee copied.
# [OK] AverageNumberOfAnnualTrainingHoursPerNonReportedGenderEmployee copied.
# [OK] AverageNumberOfAnnualTrainingHoursPerOtherGenderEmployee copied.
# [OK] BaselineYearMember copied.
# [OK] BasisForPreparation copied.
# [OK] BasisForReporting copied.
# [SKIP] BreakdownOfAnnualMassFlowOfRelevantMaterialsUsedByTheUndertakingHypercube: different shape.
# [OK] BreakdownOfEnergyConsumptionAxis copied.
# [OK] BreakdownOfEnergyConsumptionTable copied.
# [SKIP] CityOfSite: different shape.
# [SKIP] CountryOfEmploymentContractAxis: different shape.
# [OK] CountryOfPrimaryOperationsAndLocationOfSignificantAssets copied.
# [SKIP] CountryOfSite: different shape.
# [OK] DateOfAdoptionOfTransitionPlanForUndertakingNotHavingAdoptedTransitionPlanYet copied.
# [OK] DescriptionOfATargetRelatedToAPolicy copied.
# [OK] DescriptionOfATransitionPlanForClimateChangeMitigationIncludingAnExplanationOfHowItIsContributingToReduceGhgEmissions copied.
# [OK] DescriptionOfActionsTakeToAddressTheConfirmedIncidents copied.
# [OK] DescriptionOfClimateRelatedHazardsAndClimateRelatedTransitionEvents copied.
# [OK] DescriptionOfHowCircularEconomyPrinciplesAreApplied copied.
# [OK] DescriptionOfKeyElementsOfStrategyThatRelatesToOrAffectsSustainabilityIssues copied.
# [OK] DescriptionOfLimitsToTheDistributionOfProfitsConnectedToTheMutualisticNatureOrToTheNatureOfTheActivitiesConsistingInServicesOfGeneralEconomicInterestSGEI copied.
# [OK] DescriptionOfMainBusinessRelationships copied.
# [OK] DescriptionOfPracticesPoliciesAndOrFutureInitiatives copied.
# [OK] DescriptionOfSignificantGroupsOfProductsAndOrServicesOffered copied.
# [OK] DescriptionOfSignificantMarketsTheUndertakingOperatesIn copied.
# [OK] DescriptionOfSustainabilityRelatedCertificationsOrLabels copied.
# [OK] DisclosureOfAnyOtherEnvironmentalAndOrEntitySpecificEnvironmentalDisclosures copied.
# [OK] DisclosureOfAnyOtherGeneralAndOrEntitySpecificInformation copied.
# [OK] DisclosureOfAnyOtherGovernanceAndOrEntitySpecificGovernanceDisclosures copied.
# [OK] DisclosureOfAnyOtherSocialAndOrEntitySpecificSocialDisclosures copied.
# [OK] DisclosureOfHowItHasAssessedTheExposureAndSensitivityOfItsAssetsActivitiesAndValueChainToTheseHazardsAndTransitionEvents copied.
# [OK] DisclosureOfListOfMainActionsTheEntitySeeksInOrderToAchieveItsTargets copied.
# [OK] DisclosureOfWhetherItHasUndertakenClimateChangeAdaptationActionsForAnyClimateRelatedHazardsAndTransitionEvents copied.
# [OK] EmployeeCountingMethodology copied.
# [OK] EmployeeTurnoverRate copied.
# [OK] EmployeesReceivePayEqualOrAboveMinimumWageDeterminedByNationalLawOrCollectiveAgreement copied.
# [OK] EnergyConsumptionFromElectricity_NonRenewableEnergyMember copied.
# [OK] EnergyConsumptionFromElectricity_RenewableEnergyMember copied.
# [OK] EnergyConsumptionFromElectricity_TotalRenewableAndNonRenewableEnergyMember copied.
# [OK] EnergyConsumptionFromFuels_NonRenewableEnergyMember copied.
# [OK] EnergyConsumptionFromFuels_RenewableEnergyMember copied.
# [OK] EnergyConsumptionFromFuels_TotalRenewableAndNonRenewableEnergyMember copied.
# [OK] EnergyConsumptionFromSelfGeneratedElectricity_NonRenewableEnergyMember copied.
# [OK] EnergyConsumptionFromSelfGeneratedElectricity_RenewableEnergyMember copied.
# [OK] EnergyConsumptionFromSelfGeneratedElectricity_TotalRenewableAndNonRenewableEnergyMember copied.
# [OK] FemaleToMaleRatioAtManagementLevelForTheReportingPeriod copied.
# [OK] FinancialInvestmentInTheCapitalOrAssetsOfSocialEconomyEntities copied.
# [SKIP] GPSLocationOfSite: different shape.
# [OK] GenderDiversityRatioInGovernanceBody copied.
# [OK] GreenhouseGasEmissionReductionTargetBaseYear copied.
# [OK] GreenhouseGasEmissionReductionTargetYear copied.
# [OK] GrossLocationBasedScope2GreenhouseGasEmissions copied.
# [OK] GrossLocationBasedScope2GreenhouseGasEmissions_BaselineYearMember copied.
# [OK] GrossLocationBasedScope2GreenhouseGasEmissions_TargetYearMember copied.
# [OK] GrossMarketBasedScope2GreenhouseGasEmissions copied.
# [OK] GrossMarketBasedScope2GreenhouseGasEmissions_BaselineYearMember copied.
# [OK] GrossMarketBasedScope2GreenhouseGasEmissions_TargetYearMember copied.
# [OK] GrossScope1GreenhouseGasEmissions copied.
# [OK] GrossScope1GreenhouseGasEmissions_BaselineYearMember copied.
# [OK] GrossScope1GreenhouseGasEmissions_TargetYearMember copied.
# [OK] GrossScope3GreenhouseGasEmissions_BaselineYearMember copied.
# [OK] GrossScope3GreenhouseGasEmissions_CurrentlyStatedMember copied.
# [OK] GrossScope3GreenhouseGasEmissions_TargetYearMember copied.
# [SKIP] IdentifierOfMaterialTypedAxis: different shape.
# [SKIP] IdentifierOfSiteTypedAxis: different shape.
# [SKIP] IdentifierOfSitesInBiodiversitySensitiveAreasTypedAxis: different shape.
# [SKIP] IdentifierOfSubsidiaryTypedAxis: different shape.
# [OK] LinkToPreviousReportContainingDisclosuresThatRemainUnchanged copied.
# [SKIP] ListOfDisclosuresForWhichNoChangesAreReportedComparedToThePreviousPeriodReporting: different shape.
# [SKIP] ListOfOmittedDisclosuresDeemedToBeClassifiedOrSensitiveInformation: different shape.
# [SKIP] ListOfSitesTable: different shape.
# [SKIP] ListOfSubsidiaryTable: different shape.
# [SKIP] NaceSectorClassificationCodes: different shape.
# [SKIP] NameOfMaterialUsed: different shape.
# [SKIP] NameOfTheSubsidiary: different shape.
# [OK] NumberOfEmployees copied.
# [SKIP] NumberOfEmployeesForCountryOfEmploymentContract: different shape.
# [SKIP] NumberOfEmployeesForCountryOfEmploymentContractTable: different shape.
# [OK] NumberOfFatalitiesAsAResultOfWorkRelatedInjuriesAndWorkRelatedIllHealth copied.
# [OK] NumberOfFemaleEmployees copied.
# [OK] NumberOfMaleEmployees copied.
# [OK] NumberOfNonReportedGenderEmployees copied.
# [OK] NumberOfOtherGenderEmployees copied.
# [OK] NumberOfRecordableWorkRelatedAccidentsInTheReportingPeriod copied.
# [OK] NumberOfTemporaryContractEmployees copied.
# [OK] OtherUndertakingsLegalForm copied.
# [OK] PercentageGapInPayBetweenFemaleAndMaleEmployees copied.
# [OK] PercentageOfEmployeesCoveredByCollectiveBargainingAgreements copied.
# [SKIP] PostalCodeOfSite: different shape.
# [OK] PotentialAdverseEffectsOfClimateRisksThatMayAffectItsFinancialPerformanceOrBusinessOperationsInTheShortMediumOrLongTermIndicatingWhetherItAssessesTheRisksToBeHighMediumOrLow copied.
# [OK] PracticePolicyAndOrFutureInitiativeIsPubliclyAvailable copied.
# [OK] PubliclyAvailableDisclosure copied.
# [OK] RateOfRecordableWorkRelatedAccidentsInTheReportingPeriod copied.
# [SKIP] RegisteredAddressOfTheSubsidiary: different shape.
# [OK] ReportContainsDisclosuresFromThePreviousReportingPeriodThatRemainUnchanged copied.
# [OK] RevenueDerivedFromChemicalProduction copied.
# [OK] RevenueDerivedFromCoal copied.
# [OK] RevenueDerivedFromControversialWeaponsAntiPersonnelMinesClusterMunitionsChemicalWeaponsAndBiologicalWeapons copied.
# [OK] RevenueDerivedFromCultivationAndProductionOfTobacco copied.
# [OK] RevenueDerivedFromGas copied.
# [OK] RevenueDerivedFromOil copied.
# [OK] Scope1AndScope2GreenhouseGasEmissionsIntensityValueLocationBased copied.
# [OK] Scope1AndScope2GreenhouseGasEmissionsIntensityValueMarketBased copied.
# [SKIP] SiteLocatedInABiodiversitySensitiveArea: different shape.
# [SKIP] SiteLocatedNearABiodiversitySensitiveArea: different shape.
# [SKIP] SitesInBiodiversitySensitiveAreasTable: different shape.
# [OK] SpecificationOfAnyConfirmedIncidentInvolvingWorkersInTheValueChainAffectedCommunitiesConsumersAndEndUsers copied.
# [OK] SpecificationOfOtherHumanRightsRelatedToTheConfirmedIncident copied.
# [OK] SpecificationOfOtherTypesOfContentCoveredByTheCodeOfConductOrHumanRightsPolicy copied.
# [OK] SustainabilityIssueAddressedByPracticePolicyAndOrFutureInitiative copied.
# [OK] TargetYearMember copied.
# [OK] TimeHorizonsOfAnyClimateRelatedHazardsAndTransitionEventsIdentified copied.
# [OK] TotalAmountOfFinesForTheViolationOfAnticorruptionAndAntibriberyLaws copied.
# [OK] TotalAmountOfWaterWithdrawnFromAllSites copied.
# [OK] TotalEnergyConsumption copied.
# [OK] TotalGrossLocationBasedGHGEmissions_BaselineYearMember copied.
# [OK] TotalGrossLocationBasedGHGEmissions_CurrentlyStatedMember copied.
# [OK] TotalGrossLocationBasedGHGEmissions_TargetYearMember copied.
# [OK] TotalGrossLocationBasedScope1AndScope2GHGEmissions copied.
# [OK] TotalGrossLocationBasedScope1AndScope2GHGEmissions_BaselineYearMember copied.
# [OK] TotalGrossLocationBasedScope1AndScope2GHGEmissions_TargetYearMember copied.
# [OK] TotalGrossMarketBasedGHGEmissions_BaselineYearMember copied.
# [OK] TotalGrossMarketBasedGHGEmissions_CurrentlyStatedMember copied.
# [OK] TotalGrossMarketBasedGHGEmissions_TargetYearMember copied.
# [OK] TotalGrossMarketBasedScope1AndScope2GHGEmissions copied.
# [OK] TotalGrossMarketBasedScope1AndScope2GHGEmissions_BaselineYearMember copied.
# [OK] TotalGrossMarketBasedScope1AndScope2GHGEmissions_TargetYearMember copied.
# [OK] TotalHazardousWasteGeneratedMass copied.
# [OK] TotalHazardousWasteGeneratedMass_unit copied.
# [OK] TotalHazardousWasteGeneratedVolume copied.
# [OK] TotalHazardousWasteGeneratedVolume_unit copied.
# [OK] TotalLocationBasedGreenhouseGasEmissionsIntensityValue copied.
# [OK] TotalMarketBasedGreenhouseGasEmissionsIntensityValue copied.
# [OK] TotalMassOfMaterialUsed copied.
# [OK] TotalMassOfMaterialUsed_unit copied.
# [OK] TotalNatureOrientedAreaOffSite copied.
# [OK] TotalNatureOrientedAreaOffSite_unit copied.
# [OK] TotalNatureOrientedAreaOnSite copied.
# [OK] TotalNatureOrientedAreaOnSite_unit copied.
# [OK] TotalNonHazardousWasteGeneratedMass copied.
# [OK] TotalNonHazardousWasteGeneratedMass_unit copied.
# [OK] TotalNonHazardousWasteGeneratedVolume copied.
# [OK] TotalNonHazardousWasteGeneratedVolume_unit copied.
# [OK] TotalNumberOfConvictionsForTheViolationOfAntiCorruptionAndAntiBriberyLaws copied.
# [OK] TotalNumberOfSelfEmployedWorkersWithoutPersonnelThatAreWorkingExclusivelyForTheUndertaking copied.
# [OK] TotalNumberOfTemporaryWorkersProvidedByUndertakingsPrimarilyEngagedInEmploymentActivities copied.
# [OK] TotalRevenuesDerivedFromFossilFuelCoalOilAndGasSector copied.
# [OK] TotalSealedArea copied.
# [OK] TotalSealedArea_unit copied.
# [OK] TotalUseOfLand copied.
# [OK] TotalUseOfLand_unit copied.
# [OK] TotalVolumeOfMaterialUsed copied.
# [OK] TotalVolumeOfMaterialUsed_unit copied.
# [OK] TotalWasteGeneratedMass copied.
# [OK] TotalWasteGeneratedMass_unit copied.
# [OK] TotalWasteGeneratedVolume copied.
# [OK] TotalWasteGeneratedVolume_unit copied.
# [SKIP] TotalWasteRecycledReusedAndDirectedToDisposalMass: different shape.
# [SKIP] TotalWasteRecycledReusedAndDirectedToDisposalMass_unit: different shape.
# [SKIP] TotalWasteRecycledReusedAndDirectedToDisposalVolume: different shape.
# [SKIP] TotalWasteRecycledReusedAndDirectedToDisposalVolume_unit: different shape.
# [OK] TotalWaterConsumption copied.
# [OK] Turnover copied.
# [OK] TypeOfContentCoveredByTheCodeOfConductOrHumanRightsPolicyForItsOwnWorkforce copied.
# [OK] TypeOfHumanRightRelatedToTheConfirmedIncident copied.
# [OK] TypeOfNumberOfEmployees copied.
# [SKIP] TypeOfPollutantAxis: different shape.
# [SKIP] TypeOfWasteAxis: different shape.
# [OK] URLOrLinkToThePubliclyAvailableDisclosure copied.
# [OK] UndertakingAppliesCircularEconomyPrinciples copied.
# [OK] UndertakingHasACodeOfConductOrHumanRightsPolicyForItsOwnWorkforce copied.
# [OK] UndertakingHasAComplaintHandlingMechanismForItsOwnWorkforce copied.
# [OK] UndertakingHasConfirmedHumanRightsIncidentsInItsOwnWorkforce copied.
# [OK] UndertakingHasSetATargetWhichIsRelatedToAPolicy copied.
# [OK] UndertakingIsAwareOfAnyConfirmedIncidentsInvolvingWorkersInTheValueChainAffectedCommunitiesConsumersAndEndUsers copied.
# [OK] UndertakingsAreExcludedFromAnyEuReferenceBenchmarksThatAreAlignedWithTheParisAgreement copied.
# [OK] UndertakingsLegalForm copied.
# [SKIP] VolumeOfMaterialUsed: different shape.
# [SKIP] VolumeOfMaterialUsed_unit: different shape.
# [SKIP] WasteDirectedToDisposalMass: different shape.
# [SKIP] WasteDirectedToDisposalMass_unit: different shape.
# [SKIP] WasteDirectedToDisposalVolume: different shape.
# [SKIP] WasteDirectedToDisposalVolume_unit: different shape.
# [SKIP] WasteDivertedToRecycleOrReuseMass: different shape.
# [SKIP] WasteDivertedToRecycleOrReuseMass_unit: different shape.
# [SKIP] WasteDivertedToRecycleOrReuseVolume: different shape.
# [SKIP] WasteDivertedToRecycleOrReuseVolume_unit: different shape.
# [OK] WaterDischargeFromUndertakingProductionProcesses copied.
# [SKIP] WeightOfMaterialUsed: different shape.
# [SKIP] WeightOfMaterialUsed_unit: different shape.
# [OK] enum_B2 copied.
# [OK] enum_ImplementationStatus copied.
# [OK] enum_ListBiodiversityArea copied.
# [OK] enum_ListCountiesCode copied.
# [OK] enum_ListCountriesName copied.
# [OK] enum_ListDays copied.
# [OK] enum_ListDensity copied.
# [OK] enum_ListEnergy copied.
# [OK] enum_ListFuel copied.
# [OK] enum_ListHectM2 copied.
# [OK] enum_ListIdentifier copied.
# [OK] enum_ListLegalForms copied.
# [OK] enum_ListMass copied.
# [OK] enum_ListMediumOfRelease copied.
# [OK] enum_ListMonth copied.
# [OK] enum_ListNACECategories copied.
# [OK] enum_ListNACECode copied.
# [OK] enum_ListNACETechnicalName copied.
# [OK] enum_ListNCV copied.
# [OK] enum_ListOfCurrencies copied.
# [OK] enum_ListOfFutureYears copied.
# [OK] enum_ListOfPastYears copied.
# [OK] enum_ListOmittedDisclosures copied.
# [OK] enum_ListOmittedDisclosuresWithNone copied.
# [OK] enum_ListPollutants copied.
# [OK] enum_ListRenewabilityState copied.
# [OK] enum_ListStateOfMatter copied.
# [OK] enum_ListSustainabilityIssues copied.
# [SKIP] enum_ListTypeOfWastes: different shape.
# [OK] enum_ListUnitMeasurement copied.
# [OK] enum_ListUnitMeasurement_mass_only copied.
# [OK] enum_ListVolume copied.
# [OK] enum_ListVolumeMass copied.
# [OK] enum_ListWasteCategories copied.
# [OK] enum_ListYear copied.
# [OK] enum_ListYesNo copied.
# [OK] enum_employee_methodology copied.
# [OK] template_FUEL_CONVERTER copied.
# [OK] template_b10_workforce_remuneration_collective_bargaining_and_training copied.
# [OK] template_b11_convictions_and_fines_for_corruption_and_bribery copied.
# [OK] template_b1_basis_for_preparation_and_other_undertakings_general_information copied.
# [OK] template_b1_disclosure_of_sustainability_related_certifications_or_labels copied.
# [OK] template_b1_list_of_sites copied.
# [OK] template_b1_list_of_subsidiaries copied.
# [OK] template_b2_cooperative_specific_disclosures copied.
# [OK] template_b2_practices_policies_and_future_initiatives_for_transitioning_towards_a_more_sustainable_economy copied.
# [OK] template_b3_breakdown_of_energy_consumption_in_MWh copied.
# [OK] template_b3_estimated_greenhouse_gas_emissions_considering_the_GHG_protocol_version_2004_in_tCO2e copied.
# [OK] template_b3_greenhouse_gas_emission_intensity_per_turnover copied.
# [OK] template_b3_total_energy_consumption_in_MWh copied.
# [OK] template_b4_pollution_of_air_water_and_soil copied.
# [OK] template_b5_biodiversity_land_use copied.
# [OK] template_b5_sites_in_biodiversity_sensitive_areas copied.
# [OK] template_b6_water_consumption copied.
# [OK] template_b6_water_withdrawal copied.
# [OK] template_b7_annual_mass_flow_of_relevant_materials_used copied.
# [OK] template_b7_description_of_circular_economy_principles copied.
# [OK] template_b7_waste_generated copied.
# [OK] template_b8_workforce_general_characteristics_country_of_employment copied.
# [OK] template_b8_workforce_general_characteristics_gender copied.
# [OK] template_b8_workforce_general_characteristics_turnover_rate copied.
# [OK] template_b8_workforce_general_characteristics_type_of_contract copied.
# [OK] template_b9_workforce_health_and_safety copied.
# [OK] template_c1_strategy_business_model_and_sustainability copied.
# [OK] template_c2_description_of_practices_policies_and_future_initiatives_for_transitioning_towards_a_more_sustainable_economy copied.
# [OK] template_c3_GHG_reduction_targets_in_tC02e copied.
# [OK] template_c3_disclosure_of_list_of_main_actions_the_entity_seeks_in_order_to_achieve_its_targets copied.
# [OK] template_c3_transition_plan_for_undertakings_operating_in_high_climate_impact_sectors copied.
# [OK] template_c4_climate_risks copied.
# [OK] template_c5_additional_general_workforce_characteristics copied.
# [OK] template_c6_additional_own_workforce_information_human_rights_policies_and_processes copied.
# [OK] template_c7_severe_negative_human_rights_incidents copied.
# [OK] template_c8_exclusion_from_EU_reference_benchmarks copied.
# [OK] template_c8_revenues_from_certain_sectors copied.
# [OK] template_c9_gender_diversity_ratio_in_the_governance_body copied.
# [OK] template_currency copied.
# [OK] template_disclosure_of_any_other_environmental_and_or_entity_specific_enviromental_disclosures copied.
# [OK] template_disclosure_of_any_other_general_and_or_entity_specific_information_on_the_reporting_period copied.
# [OK] template_disclosure_of_any_other_governance_and_or_entity_specific_governance_disclosures copied.
# [OK] template_disclosure_of_any_other_social_and_or_entity_specific_social_disclosures copied.
# [OK] template_ending_date_display copied.
# [OK] template_further_notes copied.
# [OK] template_information_on_previous_reporting_period copied.
# [OK] template_information_on_the_report_necessary_for_XBRL copied.
# [OK] template_overall_validation_status copied.
# [OK] template_reporting_entity_identifier copied.
# [OK] template_reporting_entity_identifier_scheme copied.
# [OK] template_reporting_entity_name copied.
# [OK] template_reporting_period_display copied.
# [OK] template_reporting_period_enddate copied.
# [OK] template_reporting_period_startdate copied.
# [OK] template_reporting_schemaRef copied.
# [OK] template_reporting_template_version copied.
#
# ✅ Done! Copied 248 named ranges.

# %%
import openpyxl, sys
print("openpyxl:", openpyxl.__version__, "python:", sys.version)
# Out:
# openpyxl: 3.1.5 python: 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]
